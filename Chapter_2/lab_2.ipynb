# %%
print('fit a model with', 11, 'variables')
# Out:
# fit a model with 11 variables

# %%
print?
# Out:
# Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
# Docstring:
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
# end
#   string appended after the last value, default a newline.
# file
#   a file-like object (stream); defaults to the current sys.stdout.
# flush
#   whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %%
3+5
# Out:
# 8

# %%
'hello' + 'world'
# Out:
# 'helloworld'

# %%
x = [2,3,4]
x
# Out:
# [2, 3, 4]

# %%
y = [1,2,3]

# %%
x + y
# Out:
# [2, 3, 4, 1, 2, 3]

# %%
import numpy as np

# %%
x = np.array([2,3,4])
y = np.array([1,2,3])

# %%
x + y
# Out:
# array([3, 5, 7])

# %%
x = np.array([[2,3], [4,5]])

# %%
x
# Out:
# array([[2, 3],
#        [4, 5]])

# %%
x.ndim
# Out:
# 2

# %%
x.dtype
# Out:
# dtype('int64')

# %%
y = np.array([[6,7], [8,9]])

# %%
y.dtype
# Out:
# dtype('int64')

# %%
x.sum()
# Out:
# np.int64(14)

# %%
x.shape
# Out:
# (2, 2)

# %%
x = np.random.normal(size = 50)

# %%
x
# Out:
# array([-0.49489238,  0.02272256,  1.08838561,  0.05945552, -1.15360339,
#        -1.22836119,  0.53817158,  0.48832469, -0.00293559,  1.0735307 ,
#         1.44496226, -1.06016271, -0.10239372, -1.47455029, -0.61280831,
#        -0.22776704,  1.5119869 , -0.75177226,  0.16685162,  1.50093396,
#        -0.22357398,  2.10665045, -1.2118588 , -0.00848187, -0.16965273,
#        -0.09245403, -0.77467283,  1.43078117, -0.63650362,  0.6233302 ,
#         0.75343671, -2.28553619,  2.10447826, -0.60635024,  0.3490496 ,
#        -1.20953824,  0.00776968,  0.44238899,  1.53714206, -0.0689966 ,
#        -1.08811471,  1.00426099, -0.82272508, -1.6174747 ,  1.63234237,
#        -0.231343  ,  1.44135564, -0.12176264, -0.95051765,  1.07118845])

# %%
rng = np.random.default_rng(1303)

# %%
rng
# Out:
# Generator(PCG64) at 0x2413F6DF140

# %%
from matplotlib.pyplot import subplots

# %%
fig, ax = subplots(figsize = (8,8))
x = rng.standard_normal(100)
y = rng.standard_normal(100)
ax.plot(x,y, 'o')

# %%
fig, ax = subplots(figsize = (8,8))
ax.scatter(x,y, marker = 'o')

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2, figsize=(4,2))

ax[0].plot(x, y, 'o')
ax[0].set_title("Line Plot")

ax[1].scatter(x, y)
ax[1].set_title("Scatter Plot")

plt.show()

# %%
fig, ax = plt.subplots(nrows = 3, ncols = 3, figsize= (10,10))
ax[0,1].plot(x,y, 'o');
ax[2,2].scatter(x,y, marker = '+');

# %%
x, y
# Out:
# (array([-0.12837185, -0.6721212 ,  1.62441057,  1.57652844, -1.18949315,
#         -0.07860921, -0.91672958, -1.42968176, -0.73413498, -0.29613376,
#         -1.01480577,  0.15119946, -0.70717514, -1.44427337,  0.08834497,
#         -0.09879766, -0.17621747, -0.28369751,  0.79364672,  1.0850282 ,
#         -1.57247372,  0.60575877, -1.17072854,  0.46282421,  0.40325623,
#          2.18354342,  0.0722726 ,  0.65501348, -2.24136328, -0.85637659,
#          0.58048374,  0.37032292,  0.94715006, -1.19405127, -0.74627073,
#          1.15808147,  0.2593358 , -1.575934  ,  0.36335374,  0.82338203,
#         -1.21980611,  1.91477253,  0.94691033, -0.59321333, -0.71137748,
#          0.54965119, -0.62949934,  0.73315562, -1.55733563,  0.73278287,
#         -0.60059288,  0.8888869 , -1.31511255,  0.87023847, -0.79007327,
#          0.1757074 , -0.55996395, -0.20607363, -0.45516228,  0.64189479,
#         -0.19708568,  0.094433  ,  0.41116202,  1.13233237,  0.36259404,
#          1.34827737, -0.04850514, -0.50214402,  1.28193047, -0.80509357,
#          0.43806676,  0.60558141, -0.13793512, -1.41114655,  0.21158855,
#         -0.17070792, -0.19690911,  2.5855952 ,  1.69645675, -0.17697727,
#          0.53208519,  0.21619178,  0.97729585,  0.0308017 , -0.8076098 ,
#         -1.08042908, -0.21152021,  0.23118073,  2.06310377,  0.90642652,
#         -0.4478074 ,  0.58778781, -0.72946146,  0.78571686,  0.58776653,
#         -1.29655466, -1.38456763, -0.73346783, -2.09441819, -0.3820996 ]),
#  array([-0.96369656,  1.52845698,  0.29126702, -0.23765078, -2.46480186,
#         -0.32602753,  1.26978954, -0.28686902,  1.03321882, -0.79176977,
#         -0.5169277 ,  0.43974772, -0.02371806, -0.58758178,  0.91191208,
#         -1.45129924,  0.44300792,  0.39299927,  1.35089258, -0.07147765,
#          0.74551101,  0.20247695,  0.86760585,  0.61153509, -0.93733059,
#         -0.4371495 , -0.45994846,  1.42847014, -1.57318907, -0.86880009,
#         -1.39933962, -0.44150711,  0.37061123, -0.18699525, -0.73280589,
#         -0.04827614, -1.34660717, -0.78488568, -0.41076748,  0.31226022,
#          0.8405765 , -1.06760752,  0.09210795,  0.34930242,  0.62927041,
#         -0.2467926 , -0.86253864,  0.57779734, -0.18026414, -1.1275989 ,
#         -0.45202744,  0.75841037,  0.40740195, -0.25531043, -0.39841727,
#         -1.83810984, -0.61292114, -0.14779603,  0.13478822, -0.79757303,
#         -0.08891441,  0.35325361,  1.04818731, -0.84913929, -0.77782229,
#          0.0488303 , -0.44203313, -0.79977311,  0.18575601, -0.22209012,
#          0.26818432,  0.45975442, -0.90477435,  0.23640854, -0.8296579 ,
#          0.8140856 , -0.95074722,  1.08830959,  0.68166092,  0.25619936,
#          0.55522097, -1.48969489,  0.7438226 ,  0.43239007,  0.44296193,
#          1.03404273,  1.89078443, -0.57365418, -0.33770089, -1.90207478,
#          1.01170159,  1.43064601,  1.03506955,  0.15858387, -0.68368329,
#          0.76064302,  2.63146782, -0.70542233,  0.00570965, -0.61830103]))

# %%
fig, ax = plt.subplots(figsize=(8,8))
x = np.linspace(-np.pi*10, np.pi*10, 200)
y = np.sin(x)
ax.plot(x,y)

# %%
x = np.linspace(-10, 10, 100)
y = x**2

fig, ax = plt.subplots()

ax.plot(x, y)

# Move spines to zero position
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Hide the other spines
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Keep ticks only on bottom and left
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

plt.show()

# %%
import pandas as pd

# %%
import ISLP as islp

# %%
Auto = islp.load_data('Auto')

# %%
Auto.head()
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0         130    3504
# buick skylark 320          15.0          8         350.0         165    3693
# plymouth satellite         18.0          8         318.0         150    3436
# amc rebel sst              16.0          8         304.0         150    3433
# ford torino                17.0          8         302.0         140    3449
#
#                            acceleration  year  origin
# name
# chevrolet chevelle malibu          12.0    70       1
# buick skylark 320                  11.5    70       1
# plymouth satellite                 11.0    70       1
# amc rebel sst                      12.0    70       1
# ford torino                        10.5    70       1

# %%
Auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, chevrolet chevelle malibu to chevy s-10
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    int64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   year          392 non-null    int64
#  7   origin        392 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 27.6+ KB

# %%
Auto
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0         130    3504
# buick skylark 320          15.0          8         350.0         165    3693
# plymouth satellite         18.0          8         318.0         150    3436
# amc rebel sst              16.0          8         304.0         150    3433
# ford torino                17.0          8         302.0         140    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0          86    2790
# vw pickup                  44.0          4          97.0          52    2130
# dodge rampage              32.0          4         135.0          84    2295
# ford ranger                28.0          4         120.0          79    2625
# chevy s-10                 31.0          4         119.0          82    2720
#
#                            acceleration  year  origin
# name
# chevrolet chevelle malibu          12.0    70       1
# buick skylark 320                  11.5    70       1
# plymouth satellite                 11.0    70       1
# amc rebel sst                      12.0    70       1
# ford torino                        10.5    70       1
# ...                                 ...   ...     ...
# ford mustang gl                    15.6    82       1
# vw pickup                          24.6    82       2
# dodge rampage                      11.6    82       1
# ford ranger                        18.6    82       1
# chevy s-10                         19.4    82       1
#
# [392 rows x 8 columns]

# %%
Auto.index
# Out:
# Index(['chevrolet chevelle malibu', 'buick skylark 320', 'plymouth satellite',
#        'amc rebel sst', 'ford torino', 'ford galaxie 500', 'chevrolet impala',
#        'plymouth fury iii', 'pontiac catalina', 'amc ambassador dpl',
#        ...
#        'chrysler lebaron medallion', 'ford granada l', 'toyota celica gt',
#        'dodge charger 2.2', 'chevrolet camaro', 'ford mustang gl', 'vw pickup',
#        'dodge rampage', 'ford ranger', 'chevy s-10'],
#       dtype='object', name='name', length=392)

# %%
Auto.reset_index(inplace = True)

# %%
Auto
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0         130
# 1            buick skylark 320  15.0          8         350.0         165
# 2           plymouth satellite  18.0          8         318.0         150
# 3                amc rebel sst  16.0          8         304.0         150
# 4                  ford torino  17.0          8         302.0         140
# ..                         ...   ...        ...           ...         ...
# 387            ford mustang gl  27.0          4         140.0          86
# 388                  vw pickup  44.0          4          97.0          52
# 389              dodge rampage  32.0          4         135.0          84
# 390                ford ranger  28.0          4         120.0          79
# 391                 chevy s-10  31.0          4         119.0          82
#
#      weight  acceleration  year  origin
# 0      3504          12.0    70       1
# 1      3693          11.5    70       1
# 2      3436          11.0    70       1
# 3      3433          12.0    70       1
# 4      3449          10.5    70       1
# ..      ...           ...   ...     ...
# 387    2790          15.6    82       1
# 388    2130          24.6    82       2
# 389    2295          11.6    82       1
# 390    2625          18.6    82       1
# 391    2720          19.4    82       1
#
# [392 rows x 9 columns]

# %%
Auto.index = Auto['name']

# %%
Auto
# Out:
#                                                 name   mpg  cylinders  \
# name
# chevrolet chevelle malibu  chevrolet chevelle malibu  18.0          8
# buick skylark 320                  buick skylark 320  15.0          8
# plymouth satellite                plymouth satellite  18.0          8
# amc rebel sst                          amc rebel sst  16.0          8
# ford torino                              ford torino  17.0          8
# ...                                              ...   ...        ...
# ford mustang gl                      ford mustang gl  27.0          4
# vw pickup                                  vw pickup  44.0          4
# dodge rampage                          dodge rampage  32.0          4
# ford ranger                              ford ranger  28.0          4
# chevy s-10                                chevy s-10  31.0          4
#
#                            displacement  horsepower  weight  acceleration  \
# name
# chevrolet chevelle malibu         307.0         130    3504          12.0
# buick skylark 320                 350.0         165    3693          11.5
# plymouth satellite                318.0         150    3436          11.0
# amc rebel sst                     304.0         150    3433          12.0
# ford torino                       302.0         140    3449          10.5
# ...                                 ...         ...     ...           ...
# ford mustang gl                   140.0          86    2790          15.6
# vw pickup                          97.0          52    2130          24.6
# dodge rampage                     135.0          84    2295          11.6
# ford ranger                       120.0          79    2625          18.6
# chevy s-10                        119.0          82    2720          19.4
#
#                            year  origin
# name
# chevrolet chevelle malibu    70       1
# buick skylark 320            70       1
# plymouth satellite           70       1
# amc rebel sst                70       1
# ford torino                  70       1
# ...                         ...     ...
# ford mustang gl              82       1
# vw pickup                    82       2
# dodge rampage                82       1
# ford ranger                  82       1
# chevy s-10                   82       1
#
# [392 rows x 9 columns]

# %%
Auto.drop('name', axis = 1, inplace = True)

# %%
Auto
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0         130    3504
# buick skylark 320          15.0          8         350.0         165    3693
# plymouth satellite         18.0          8         318.0         150    3436
# amc rebel sst              16.0          8         304.0         150    3433
# ford torino                17.0          8         302.0         140    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0          86    2790
# vw pickup                  44.0          4          97.0          52    2130
# dodge rampage              32.0          4         135.0          84    2295
# ford ranger                28.0          4         120.0          79    2625
# chevy s-10                 31.0          4         119.0          82    2720
#
#                            acceleration  year  origin
# name
# chevrolet chevelle malibu          12.0    70       1
# buick skylark 320                  11.5    70       1
# plymouth satellite                 11.0    70       1
# amc rebel sst                      12.0    70       1
# ford torino                        10.5    70       1
# ...                                 ...   ...     ...
# ford mustang gl                    15.6    82       1
# vw pickup                          24.6    82       2
# dodge rampage                      11.6    82       1
# ford ranger                        18.6    82       1
# chevy s-10                         19.4    82       1
#
# [392 rows x 8 columns]

# %%
Auto.reset_index(inplace = True)

# %%
Auto
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0         130
# 1            buick skylark 320  15.0          8         350.0         165
# 2           plymouth satellite  18.0          8         318.0         150
# 3                amc rebel sst  16.0          8         304.0         150
# 4                  ford torino  17.0          8         302.0         140
# ..                         ...   ...        ...           ...         ...
# 387            ford mustang gl  27.0          4         140.0          86
# 388                  vw pickup  44.0          4          97.0          52
# 389              dodge rampage  32.0          4         135.0          84
# 390                ford ranger  28.0          4         120.0          79
# 391                 chevy s-10  31.0          4         119.0          82
#
#      weight  acceleration  year  origin
# 0      3504          12.0    70       1
# 1      3693          11.5    70       1
# 2      3436          11.0    70       1
# 3      3433          12.0    70       1
# 4      3449          10.5    70       1
# ..      ...           ...   ...     ...
# 387    2790          15.6    82       1
# 388    2130          24.6    82       2
# 389    2295          11.6    82       1
# 390    2625          18.6    82       1
# 391    2720          19.4    82       1
#
# [392 rows x 9 columns]

# %%
Auto['horsepower']
# Out:
# 0      130
# 1      165
# 2      150
# 3      150
# 4      140
#       ...
# 387     86
# 388     52
# 389     84
# 390     79
# 391     82
# Name: horsepower, Length: 392, dtype: int64

# %%
Auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          392 non-null    object
#  1   mpg           392 non-null    float64
#  2   cylinders     392 non-null    int64
#  3   displacement  392 non-null    float64
#  4   horsepower    392 non-null    int64
#  5   weight        392 non-null    int64
#  6   acceleration  392 non-null    float64
#  7   year          392 non-null    int64
#  8   origin        392 non-null    int64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 27.7+ KB

# %%
Auto.unique['horsepower']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17248\2979969534.py in ?()
# ----> 1 Auto.unique['horsepower']
#
# f:\Python\ISLP\islp_env\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
np.unique(Auto['horsepower'])
# Out:
# array([ 46,  48,  49,  52,  53,  54,  58,  60,  61,  62,  63,  64,  65,
#         66,  67,  68,  69,  70,  71,  72,  74,  75,  76,  77,  78,  79,
#         80,  81,  82,  83,  84,  85,  86,  87,  88,  89,  90,  91,  92,
#         93,  94,  95,  96,  97,  98, 100, 102, 103, 105, 107, 108, 110,
#        112, 113, 115, 116, 120, 122, 125, 129, 130, 132, 133, 135, 137,
#        138, 139, 140, 142, 145, 148, 149, 150, 152, 153, 155, 158, 160,
#        165, 167, 170, 175, 180, 190, 193, 198, 200, 208, 210, 215, 220,
#        225, 230])

# %%
Auto[:3]
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0         130
# 1          buick skylark 320  15.0          8         350.0         165
# 2         plymouth satellite  18.0          8         318.0         150
#
#    weight  acceleration  year  origin
# 0    3504          12.0    70       1
# 1    3693          11.5    70       1
# 2    3436          11.0    70       1

# %%
Auto.tail()
# Out:
#                 name   mpg  cylinders  displacement  horsepower  weight  \
# 387  ford mustang gl  27.0          4         140.0          86    2790
# 388        vw pickup  44.0          4          97.0          52    2130
# 389    dodge rampage  32.0          4         135.0          84    2295
# 390      ford ranger  28.0          4         120.0          79    2625
# 391       chevy s-10  31.0          4         119.0          82    2720
#
#      acceleration  year  origin
# 387          15.6    82       1
# 388          24.6    82       2
# 389          11.6    82       1
# 390          18.6    82       1
# 391          19.4    82       1

# %%
idx_80 = Auto['year'] > 80
idx_80
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 387     True
# 388     True
# 389     True
# 390     True
# 391     True
# Name: year, Length: 392, dtype: bool

# %%
Auto[idx_80]
# Out:
#                                   name   mpg  cylinders  displacement  \
# 334                   plymouth reliant  27.2          4         135.0
# 335                      buick skylark  26.6          4         151.0
# 336             dodge aries wagon (sw)  25.8          4         156.0
# 337                 chevrolet citation  23.5          6         173.0
# 338                   plymouth reliant  30.0          4         135.0
# 339                     toyota starlet  39.1          4          79.0
# 340                     plymouth champ  39.0          4          86.0
# 341                   honda civic 1300  35.1          4          81.0
# 342                             subaru  32.3          4          97.0
# 343                     datsun 210 mpg  37.0          4          85.0
# 344                      toyota tercel  37.7          4          89.0
# 345                        mazda glc 4  34.1          4          91.0
# 346                 plymouth horizon 4  34.7          4         105.0
# 347                     ford escort 4w  34.4          4          98.0
# 348                     ford escort 2h  29.9          4          98.0
# 349                   volkswagen jetta  33.0          4         105.0
# 350                      honda prelude  33.7          4         107.0
# 351                     toyota corolla  32.4          4         108.0
# 352                       datsun 200sx  32.9          4         119.0
# 353                          mazda 626  31.6          4         120.0
# 354          peugeot 505s turbo diesel  28.1          4         141.0
# 355                       volvo diesel  30.7          6         145.0
# 356                    toyota cressida  25.4          6         168.0
# 357                  datsun 810 maxima  24.2          6         146.0
# 358                      buick century  22.4          6         231.0
# 359              oldsmobile cutlass ls  26.6          8         350.0
# 360                    ford granada gl  20.2          6         200.0
# 361             chrysler lebaron salon  17.6          6         225.0
# 362                 chevrolet cavalier  28.0          4         112.0
# 363           chevrolet cavalier wagon  27.0          4         112.0
# 364          chevrolet cavalier 2-door  34.0          4         112.0
# 365         pontiac j2000 se hatchback  31.0          4         112.0
# 366                     dodge aries se  29.0          4         135.0
# 367                    pontiac phoenix  27.0          4         151.0
# 368               ford fairmont futura  24.0          4         140.0
# 369                volkswagen rabbit l  36.0          4         105.0
# 370                 mazda glc custom l  37.0          4          91.0
# 371                   mazda glc custom  31.0          4          91.0
# 372             plymouth horizon miser  38.0          4         105.0
# 373                     mercury lynx l  36.0          4          98.0
# 374                   nissan stanza xe  36.0          4         120.0
# 375                       honda accord  36.0          4         107.0
# 376                     toyota corolla  34.0          4         108.0
# 377                        honda civic  38.0          4          91.0
# 378                 honda civic (auto)  32.0          4          91.0
# 379                      datsun 310 gx  38.0          4          91.0
# 380              buick century limited  25.0          6         181.0
# 381  oldsmobile cutlass ciera (diesel)  38.0          6         262.0
# 382         chrysler lebaron medallion  26.0          4         156.0
# 383                     ford granada l  22.0          6         232.0
# 384                   toyota celica gt  32.0          4         144.0
# 385                  dodge charger 2.2  36.0          4         135.0
# 386                   chevrolet camaro  27.0          4         151.0
# 387                    ford mustang gl  27.0          4         140.0
# 388                          vw pickup  44.0          4          97.0
# 389                      dodge rampage  32.0          4         135.0
# 390                        ford ranger  28.0          4         120.0
# 391                         chevy s-10  31.0          4         119.0
#
#      horsepower  weight  acceleration  year  origin
# 334          84    2490          15.7    81       1
# 335          84    2635          16.4    81       1
# 336          92    2620          14.4    81       1
# 337         110    2725          12.6    81       1
# 338          84    2385          12.9    81       1
# 339          58    1755          16.9    81       3
# 340          64    1875          16.4    81       1
# 341          60    1760          16.1    81       3
# 342          67    2065          17.8    81       3
# 343          65    1975          19.4    81       3
# 344          62    2050          17.3    81       3
# 345          68    1985          16.0    81       3
# 346          63    2215          14.9    81       1
# 347          65    2045          16.2    81       1
# 348          65    2380          20.7    81       1
# 349          74    2190          14.2    81       2
# 350          75    2210          14.4    81       3
# 351          75    2350          16.8    81       3
# 352         100    2615          14.8    81       3
# 353          74    2635          18.3    81       3
# 354          80    3230          20.4    81       2
# 355          76    3160          19.6    81       2
# 356         116    2900          12.6    81       3
# 357         120    2930          13.8    81       3
# 358         110    3415          15.8    81       1
# 359         105    3725          19.0    81       1
# 360          88    3060          17.1    81       1
# 361          85    3465          16.6    81       1
# 362          88    2605          19.6    82       1
# 363          88    2640          18.6    82       1
# 364          88    2395          18.0    82       1
# 365          85    2575          16.2    82       1
# 366          84    2525          16.0    82       1
# 367          90    2735          18.0    82       1
# 368          92    2865          16.4    82       1
# 369          74    1980          15.3    82       2
# 370          68    2025          18.2    82       3
# 371          68    1970          17.6    82       3
# 372          63    2125          14.7    82       1
# 373          70    2125          17.3    82       1
# 374          88    2160          14.5    82       3
# 375          75    2205          14.5    82       3
# 376          70    2245          16.9    82       3
# 377          67    1965          15.0    82       3
# 378          67    1965          15.7    82       3
# 379          67    1995          16.2    82       3
# 380         110    2945          16.4    82       1
# 381          85    3015          17.0    82       1
# 382          92    2585          14.5    82       1
# 383         112    2835          14.7    82       1
# 384          96    2665          13.9    82       3
# 385          84    2370          13.0    82       1
# 386          90    2950          17.3    82       1
# 387          86    2790          15.6    82       1
# 388          52    2130          24.6    82       2
# 389          84    2295          11.6    82       1
# 390          79    2625          18.6    82       1
# 391          82    2720          19.4    82       1

# %%
fig, ax = plt.subplots(figsize = (8,8))
ax.plot(Auto['horsepower'], Auto['mpg'], 'o')

# %%
ax = Auto.plot.scatter('horsepower', 'mpg')
ax.set_title('MPG vs Horsepower')
# Out:
# Text(0.5, 1.0, 'MPG vs Horsepower')
